# %% [markdown]
# # 2. Pandas 라이브러리를 활용한 데이터 수집

# %% [markdown]
# # 4. 데이터 불러오기 from web (BeautifulSoup 라이브러리)

# %% [markdown]
# # 4.1 데이터 불러오기 from web

# %%
import requests, bs4, pandas as pd

# %%
#웹페이지 html소스 가져오기
weather = requests.get('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp')
weather.encoding='utf-8'

# %%
html = weather.text

# %%
bs = bs4.BeautifulSoup(html,'html.parser')
bs
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2018년 06월 17일 (일)요일 06:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2018년 06월 17일 (일)요일 06:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# <header>
# <title>전국 육상중기예보</title>
# <tm>201806170600</tm>
# <wf><![CDATA[기압골의 영향으로 22일은 제주도에 비가 오겠고, 그 밖의 날은 고기압의 가장자리에 들어 구름많은 날이 많겠습니다.  <br />기온은 평년(최저기온: 16~20도, 최고기온: 23~29도)과 비슷하거나 조금 높겠습니다.<br />강수량은 평년(3~19mm)보다 적겠으나, 제주도는 비슷하겠습니다.]]></wf>
# </header>
# <body>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>서울</city>
# <data>
# <mode>A02</mode>
# <tmef>2018-06-20 00:00</tmef>
# ...

# %%
# html 구조 태그로 가져오기
title = bs.find("title").text
title
# Out:
# '기상청 육상 중기예보'

# %%
tm = bs.find("tm").text
tm
# Out:
# '201806170600'

# %%
wf = bs.find("wf").text
wf
# Out:
# '기압골의 영향으로 22일은 제주도에 비가 오겠고, 그 밖의 날은 고기압의 가장자리에 들어 구름많은 날이 많겠습니다.  <br />기온은 평년(최저기온: 16~20도, 최고기온: 23~29도)과 비슷하거나 조금 높겠습니다.<br />강수량은 평년(3~19mm)보다 적겠으나, 제주도는 비슷하겠습니다.'

# %% [markdown]
# # 4.2 데이터 불러오기 from web [태그 찾기-find]

# %%
bs = bs4.BeautifulSoup(html,"html.parser")

# %%
# div에서 클래스가 class_db_quiz인것만 추출
divs = bs.find or fiinAll("태그명")
print(divs)
# Out:
# <bound method Tag.find of <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2018년 06월 17일 (일)요일 06:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2018년 06월 17일 (일)요일 06:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# <header>
# <title>전국 육상중기예보</title>
# <tm>201806170600</tm>
# <wf><![CDATA[기압골의 영향으로 22일은 제주도에 비가 오겠고, 그 밖의 날은 고기압의 가장자리에 들어 구름많은 날이 많겠습니다.  <br />기온은 평년(최저기온: 16~20도, 최고기온: 23~29도)과 비슷하거나 조금 높겠습니다.<br />강수량은 평년(3~19mm)보다 적겠으나, 제주도는 비슷하겠습니다.]]></wf>
# </header>
# <body>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>서울</city>
# <data>
# <mode>A02</mode>
# ...

# %%
import requests, bs4,pandas as pd,numpy as np

# %%
# 웹페이지 html소스 가져오기
rsp = requests.get('http://13.209.33.89:3333/quiz')
rsp
# Out:
# <Response [200]>

# %%
rsp.encoding = 'utf-8'

# %%
source = rsp.text
source
# Out:
# '<!-- ncluding header content which is common for all pages\r\n-->\r\n\n<html>\n<head>\n        <title></title>\n       <link rel=\'stylesheet\' href=\'/css/styleFile.css\' />\n    </head>\n    <body>\n    \t<ul>\n\t\t  <li><a class="active" href="/">Home</a></li>\n\t\t  <li><a href="/quiz"> Quiz </a></li>\n\t\t  <li><a href="/maps/add">좌표 등록</a></li>\n\t\t  <li><a href="/maps">등록좌표 목록</a></li>\n\t\t  <li><a href="/maps/geomap">지도 화면</a></li>\n\t\t  <li><a href="/maps/chart">파이차트 화면</a></li>\n\t\t  <li><a href="/maps/chartLine">라인차트 화면</a></li>\n\t\t\t\t<li><a href="/maps/gitList">git저장소 목록</a></li>\n\t\t\t\t <li><a href="/test">test</a></li> \n\t\t</ul>\n<!--         <div>\n            <a href="/">Home</a> | \n            <a href="/quiz"> Quiz </a> | \n            <a href="/maps/add">Add New Location</a> | \n            <a href="/maps">All Location List</a>  |\n            <a href="/maps/geomap">Geolocation Map</a>  |\n            <a href="/maps/chart">Chart</a> \n        </div>  --
# ...

# %%
bss = bs4.BeautifulSoup(source,'html.parser')
bss
# Out:
# <!-- ncluding header content which is common for all pages
# -->
# <html>
# <head>
# <title></title>
# <link href="/css/styleFile.css" rel="stylesheet"/>
# </head>
# <body>
# <ul>
# <li><a class="active" href="/">Home</a></li>
# <li><a href="/quiz"> Quiz </a></li>
# <li><a href="/maps/add">좌표 등록</a></li>
# <li><a href="/maps">등록좌표 목록</a></li>
# <li><a href="/maps/geomap">지도 화면</a></li>
# <li><a href="/maps/chart">파이차트 화면</a></li>
# <li><a href="/maps/chartLine">라인차트 화면</a></li>
# <li><a href="/maps/gitList">git저장소 목록</a></li>
# <li><a href="/test">test</a></li>
# </ul>
# <!--         <div>
#             <a href="/">Home</a> |
#             <a href="/quiz"> Quiz </a> |
#             <a href="/maps/add">Add New Location</a> |
#             <a href="/maps">All Location List</a>  |
#             <a href="/maps/geomap">Geolocation Map</a>  |
#             <a href="/maps/chart">Chart</a>
#         </div>  -->
# <h1></h1>
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# ...

# %%
# html 부분구조 가져오기
find_tag = bss.find("div")
find_tag
# Out:
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSev5NqrIRccYJ1kWq1dPBDXvX4MJ7ugr-GVi5A_bgEig1dsHA/viewform?usp=sf_link"> 6/15 파이썬 스크랩 BS4</a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScoGQuidGNCFerQZ6Dw5t6PndPPT62EvrncPLL3xLUfulRTyA/viewform?usp=sf_link"> 6/14 파이썬 데이터 불러오기/저장하기 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSftZ-2VYfHB46FrwFG2HjbRDBtLSO0XP2BmiHh3iqwGoi3pQQ/viewform?usp=sf_link"> 6/8 postgres 과제 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSeZBKjrZD1nAf4aAYhz_WEAqbzwPUPihgMEfXy74e0IMRwXKw/viewform?usp=sf_link"> 6/8 파이썬 제어문 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdvFbZGNm7rSGQO_daDSWHC8o1BNgZtIBajLaiOcvgV2iV0IA/viewform?usp=sf_link"> 6/7 파이썬 자료형 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSehRuBYKpXNULxkamM8zVOd_mkFwZYwKtAp8Px0Kl0oCJbIeA/viewform?usp=sf_link"> 5/31 파이썬 머신러닝 </a>
# ...

# %% [markdown]
# # 4.3 데이터 불러오기 from web [속성 찾기] / 변수 = bs.findAll or find(“태그명”, {“속성명”:”속성이름“})

# %%
bs = bs4.BeautifulSoup(html,"html.parser")
# findAll :모두찾기 find: 한개만
findAttr = bs.findAll or find("태그명",{"속성명":"속성이름"})

# %%
import requests, bs4, pandas as pd, numpy as np

# %%
# 웹페이지 html 소스 가져오기
htmlSource = requests.get('http://13.209.33.89:3333/quiz')
htmlSource
# Out:
# <Response [200]>

# %%
htmlSource.encoding='utf-8'

# %%
encodingDone = htmlSource.text
encodingDone
# Out:
# '<!-- ncluding header content which is common for all pages\r\n-->\r\n\n<html>\n<head>\n        <title></title>\n       <link rel=\'stylesheet\' href=\'/css/styleFile.css\' />\n    </head>\n    <body>\n    \t<ul>\n\t\t  <li><a class="active" href="/">Home</a></li>\n\t\t  <li><a href="/quiz"> Quiz </a></li>\n\t\t  <li><a href="/maps/add">좌표 등록</a></li>\n\t\t  <li><a href="/maps">등록좌표 목록</a></li>\n\t\t  <li><a href="/maps/geomap">지도 화면</a></li>\n\t\t  <li><a href="/maps/chart">파이차트 화면</a></li>\n\t\t  <li><a href="/maps/chartLine">라인차트 화면</a></li>\n\t\t\t\t<li><a href="/maps/gitList">git저장소 목록</a></li>\n\t\t\t\t <li><a href="/test">test</a></li> \n\t\t</ul>\n<!--         <div>\n            <a href="/">Home</a> | \n            <a href="/quiz"> Quiz </a> | \n            <a href="/maps/add">Add New Location</a> | \n            <a href="/maps">All Location List</a>  |\n            <a href="/maps/geomap">Geolocation Map</a>  |\n            <a href="/maps/chart">Chart</a> \n        </div>  --
# ...

# %%
SourceDone = bs4.BeautifulSoup(encodingDone,'html.parser')
SourceDone
# Out:
# <!-- ncluding header content which is common for all pages
# -->
# <html>
# <head>
# <title></title>
# <link href="/css/styleFile.css" rel="stylesheet"/>
# </head>
# <body>
# <ul>
# <li><a class="active" href="/">Home</a></li>
# <li><a href="/quiz"> Quiz </a></li>
# <li><a href="/maps/add">좌표 등록</a></li>
# <li><a href="/maps">등록좌표 목록</a></li>
# <li><a href="/maps/geomap">지도 화면</a></li>
# <li><a href="/maps/chart">파이차트 화면</a></li>
# <li><a href="/maps/chartLine">라인차트 화면</a></li>
# <li><a href="/maps/gitList">git저장소 목록</a></li>
# <li><a href="/test">test</a></li>
# </ul>
# <!--         <div>
#             <a href="/">Home</a> |
#             <a href="/quiz"> Quiz </a> |
#             <a href="/maps/add">Add New Location</a> |
#             <a href="/maps">All Location List</a>  |
#             <a href="/maps/geomap">Geolocation Map</a>  |
#             <a href="/maps/chart">Chart</a>
#         </div>  -->
# <h1></h1>
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# ...

# %%
# html 태그 속성으로 찾기
find_attr = SourceDone.find("div",{"id":"id_db_quiz"})
find_attr
# Out:
# <div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link"> 6/5 오라클 GroupBy 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link"> 5/29 오라클 숫자/날짜 및 고급함수 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link"> 5/15 오라클 데이터 조회(함수활용)  </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link"> 5/8 오라클 원격접속 및 조회 </a>
# <p></p>
# ...

# %% [markdown]
# # 4.4 [속성 찾기] / 변수 = bs.findAll or find(“태그명”, {“속성명[id or class]”:”속성이름“})

# %%
import requests, bs4, pandas as pd, numpy as np

# %%
# 웹페이지 html 소스 가져오기
respond = requests.get('http://13.209.33.89:3333/quiz')

# %%
respond.encoding='utf-8'

# %%
sourceData = respond.text
sourceData
# Out:
# '<!-- ncluding header content which is common for all pages\r\n-->\r\n\n<html>\n<head>\n        <title></title>\n       <link rel=\'stylesheet\' href=\'/css/styleFile.css\' />\n    </head>\n    <body>\n    \t<ul>\n\t\t  <li><a class="active" href="/">Home</a></li>\n\t\t  <li><a href="/quiz"> Quiz </a></li>\n\t\t  <li><a href="/maps/add">좌표 등록</a></li>\n\t\t  <li><a href="/maps">등록좌표 목록</a></li>\n\t\t  <li><a href="/maps/geomap">지도 화면</a></li>\n\t\t  <li><a href="/maps/chart">파이차트 화면</a></li>\n\t\t  <li><a href="/maps/chartLine">라인차트 화면</a></li>\n\t\t\t\t<li><a href="/maps/gitList">git저장소 목록</a></li>\n\t\t\t\t <li><a href="/test">test</a></li> \n\t\t</ul>\n<!--         <div>\n            <a href="/">Home</a> | \n            <a href="/quiz"> Quiz </a> | \n            <a href="/maps/add">Add New Location</a> | \n            <a href="/maps">All Location List</a>  |\n            <a href="/maps/geomap">Geolocation Map</a>  |\n            <a href="/maps/chart">Chart</a> \n        </div>  --
# ...

# %%
biAss = bs4.BeautifulSoup(sourceData,'html.parser')
biAss
# Out:
# <!-- ncluding header content which is common for all pages
# -->
# <html>
# <head>
# <title></title>
# <link href="/css/styleFile.css" rel="stylesheet"/>
# </head>
# <body>
# <ul>
# <li><a class="active" href="/">Home</a></li>
# <li><a href="/quiz"> Quiz </a></li>
# <li><a href="/maps/add">좌표 등록</a></li>
# <li><a href="/maps">등록좌표 목록</a></li>
# <li><a href="/maps/geomap">지도 화면</a></li>
# <li><a href="/maps/chart">파이차트 화면</a></li>
# <li><a href="/maps/chartLine">라인차트 화면</a></li>
# <li><a href="/maps/gitList">git저장소 목록</a></li>
# <li><a href="/test">test</a></li>
# </ul>
# <!--         <div>
#             <a href="/">Home</a> |
#             <a href="/quiz"> Quiz </a> |
#             <a href="/maps/add">Add New Location</a> |
#             <a href="/maps">All Location List</a>  |
#             <a href="/maps/geomap">Geolocation Map</a>  |
#             <a href="/maps/chart">Chart</a>
#         </div>  -->
# <h1></h1>
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# ...

# %%
# html 태그 속성으로 찾기
find_attribute = biAss.find("div",{"id":"id_db_quiz"})
find_attribute
# Out:
# <div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScP3ojzBNFbKbTFq4r58GqqZODYom1d6jrn09rmdqT57uByVA/viewform?usp=sf_link"> 6/5 오라클 GroupBy 퀴즈 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfU5Pv_GQOLV-SkrDirOGt4GLDP3sZpy-UPY4zsud2ODPknbA/viewform?usp=sf_link"> 5/29 오라클 숫자/날짜 및 고급함수 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdFuYrwaYE6HEzQft21Icj_2yPyQqkcSabuvnaWwO47v99XmA/viewform?usp=sf_link"> 5/15 오라클 데이터 조회(함수활용)  </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSd8MAsXIKIteOM4OFCggUoYeOqC5aGI-2aQFLV8533HkbTz-w/viewform?usp=sf_link"> 5/8 오라클 원격접속 및 조회 </a>
# <p></p>
# ...

# %% [markdown]
# # 4.5 [태그 내 DOM 부분구조]

# %%
# bs = bs4.BeautifulSoup(html,"html.parser")
# #findAll : 모두 찾기 find : 한개만
# findAttr = bs.findAll or find("태그명",{"속성명":"속성이름"})
# find_part = find_attr:find("a")

# %%
import requests, bs4, pandas as pd, numpy as np

# %%
# 웹페이지 html 소스 가져오기
respondd = requests.get('http://13.209.33.89:3333/quiz')

# %%
respondd.encoding ='utf-8'

# %%
htmlll=respondd.text

# %%
htmlll
# Out:
# '<!-- ncluding header content which is common for all pages\r\n-->\r\n\n<html>\n<head>\n        <title></title>\n       <link rel=\'stylesheet\' href=\'/css/styleFile.css\' />\n    </head>\n    <body>\n    \t<ul>\n\t\t  <li><a class="active" href="/">Home</a></li>\n\t\t  <li><a href="/quiz"> Quiz </a></li>\n\t\t  <li><a href="/maps/add">좌표 등록</a></li>\n\t\t  <li><a href="/maps">등록좌표 목록</a></li>\n\t\t  <li><a href="/maps/geomap">지도 화면</a></li>\n\t\t  <li><a href="/maps/chart">파이차트 화면</a></li>\n\t\t  <li><a href="/maps/chartLine">라인차트 화면</a></li>\n\t\t\t\t<li><a href="/maps/gitList">git저장소 목록</a></li>\n\t\t\t\t <li><a href="/test">test</a></li> \n\t\t</ul>\n<!--         <div>\n            <a href="/">Home</a> | \n            <a href="/quiz"> Quiz </a> | \n            <a href="/maps/add">Add New Location</a> | \n            <a href="/maps">All Location List</a>  |\n            <a href="/maps/geomap">Geolocation Map</a>  |\n            <a href="/maps/chart">Chart</a> \n        </div>  --
# ...

# %%
bsss = bs4.BeautifulSoup(htmlll,'html.parser')

# %%
# html부분구조 가져오기
find_attrr = bsss.find("div",{"id":"id_db_quiz"})
find_part = find_attrr.find("a")
find_part
# Out:
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>

# %% [markdown]
# # dom 구조 내 속성 찾기

# %%
i = find_part.attrs['href']
# Out:
# 'https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link'

# %% [markdown]
# # 35page - 퀴즈내 링크만 전부 FOR LOOP를 활용하여 추출하세요!

# %%
import requests,bs4,pandas as pd, numpy as np

# %%
#웹페이지 html소스 가져오기
resp = requests.get('http://13.209.33.89:3333/quiz')

# %%
resp.encoding='utf-8'

# %%
html = resp.text
html
# Out:
# '<!-- ncluding header content which is common for all pages\r\n-->\r\n\n<html>\n<head>\n        <title></title>\n       <link rel=\'stylesheet\' href=\'/css/styleFile.css\' />\n    </head>\n    <body>\n    \t<ul>\n\t\t  <li><a class="active" href="/">Home</a></li>\n\t\t  <li><a href="/quiz"> Quiz </a></li>\n\t\t  <li><a href="/maps/add">좌표 등록</a></li>\n\t\t  <li><a href="/maps">등록좌표 목록</a></li>\n\t\t  <li><a href="/maps/geomap">지도 화면</a></li>\n\t\t  <li><a href="/maps/chart">파이차트 화면</a></li>\n\t\t  <li><a href="/maps/chartLine">라인차트 화면</a></li>\n\t\t\t\t<li><a href="/maps/gitList">git저장소 목록</a></li>\n\t\t\t\t <li><a href="/test">test</a></li> \n\t\t</ul>\n<!--         <div>\n            <a href="/">Home</a> | \n            <a href="/quiz"> Quiz </a> | \n            <a href="/maps/add">Add New Location</a> | \n            <a href="/maps">All Location List</a>  |\n            <a href="/maps/geomap">Geolocation Map</a>  |\n            <a href="/maps/chart">Chart</a> \n        </div>  --
# ...

# %%
bs = bs4.BeautifulSoup(html,'html.parser')

# %%
# html 부분구조 가져오기
find_part = bs.findAll("a")
find_part
# Out:
# [<a class="active" href="/">Home</a>,
#  <a href="/quiz"> Quiz </a>,
#  <a href="/maps/add">좌표 등록</a>,
#  <a href="/maps">등록좌표 목록</a>,
#  <a href="/maps/geomap">지도 화면</a>,
#  <a href="/maps/chart">파이차트 화면</a>,
#  <a href="/maps/chartLine">라인차트 화면</a>,
#  <a href="/maps/gitList">git저장소 목록</a>,
#  <a href="/test">test</a>,
#  <a href="https://docs.google.com/forms/d/e/1FAIpQLSev5NqrIRccYJ1kWq1dPBDXvX4MJ7ugr-GVi5A_bgEig1dsHA/viewform?usp=sf_link"> 6/15 파이썬 스크랩 BS4</a>,
#  <a href="https://docs.google.com/forms/d/e/1FAIpQLScoGQuidGNCFerQZ6Dw5t6PndPPT62EvrncPLL3xLUfulRTyA/viewform?usp=sf_link"> 6/14 파이썬 데이터 불러오기/저장하기 </a>,
#  <a href="https://docs.google.com/forms/d/e/1FAIpQLSftZ-2VYfHB46FrwFG2HjbRDBtLSO0XP2BmiHh3iqwGoi3pQQ/viewform?usp=sf_link"> 6/8 postgres 과제 </a>,
#  <a href="https://docs.google.com/forms/d/e/1FAIpQLSeZBKjrZD1nAf4aAYhz_WEAqbzwPUPihgMEfXy74e0IMRwXKw/viewform?usp=sf_link"> 6/8 파이썬 제어문 </a>,
# ...

# %%
# 링크 내 속성 가져오기
link = find_part.findAll
