# %% [markdown]
# # < 1차원 차트 꾸미기 >

# %% [markdown]
# # 차트의 색 및 내용 채우기

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
size = 50

x = np.linspace(1,10,10)
y = np.linspace(1,20,10)
y2= x**2
print(type(y2))
plt.plot(x,y2)
# Out:
# <class 'numpy.ndarray'>

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
size = 50
#사이즈만큰 랜덤한 데이터 생성 (정규분포: 평균0, 표준편차1)
y=np.random.standard_normal(size)
x=range(size)
# 차트 꾸미기
plt.plot(x,y, 'b', lw=1.5) #차트 선색 및 크기설정
plt.plot(x,y, 'o', ) #차트 내 'o' 표기
plt.grid(True) #그리드 표기
plt.xlabel('index') # x축 라벨
plt.ylabel('value') # y축 라벨
plt.title('Simple plot') # 차트 제목
# Out:
# Text(0.5,1,'Simple plot')

# %% [markdown]
# # 차트의 선색 및 크기 설정

# %% [markdown]
# #필요 라이브러리 정의
# import numpy as np
# import matplotlib.pyplot as plt
#
# # 커맨드뷰에서 차트 시연
# %matplotlib inline
# size = 50
# #사이즈만큰 랜덤한 데이터 생성 (정규분포: 평균0, 표준편차1)
# y=np.random.standard_normal(size)
# x=range(size)
#
# # 차트 꾸미기
# # plt.plot(x,y, 'b', lw=1.5) #차트 선색 및 크기설정
# plt.plot(x,y, 'g--', lw=1.5) #초록색, 점선

# %% [markdown]
# # 선 종류 변경

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
size = 50
#사이즈만큰 랜덤한 데이터 생성 (정규분포: 평균0, 표준편차1)
y=np.random.standard_normal(size)
x=range(size)

# 차트 꾸미기
plt.plot(x,y,'b--') #차트 선색 및 크기설정

# %% [markdown]
# # 라벨과 제목

# %% [markdown]
# #필요 라이브러리 정의
# import numpy as np
# import matplotlib.pyplot as plt
#
# # 커맨드뷰에서 차트 시연
# %matplotlib inline
# size = 50
# #사이즈만큰 랜덤한 데이터 생성 (정규분포: 평균0, 표준편차1)
# y=np.random.standard_normal(size)
# x=range(size)
#
# plt.plot()
# # 차트 꾸미기
# plt.xlabel('index') # x축 라벨
# plt.ylabel('value') # y축 라벨
# plt.title('Simple plot') # 차트 제목

# %% [markdown]
# # 특정구간 확대

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
size = 50

x = np.linspace(1,10,10)
y = np.linspace(1,20,10)

# 차트 꾸미기
plt.plot(x,y, "b--") #차트 선색 및 크기설정
plt.xlim(2,3)
plt.ylim(0,10)
# Out:
# (0, 10)

# %% [markdown]
# # 레전드 설정

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
size = 50

x = np.linspace(1,10,10)
y = np.linspace(1,20,10)
y2= x**2
# 차트 꾸미기
plt.plot(x,y, "b--", label="first") #차트 선색 및 크기설정
plt.plot(x,y2, "r--", label="second") #차트 선색 및 크기설정
plt.legend("aaa","bbb",loc=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\legend.py:936: UserWarning: Legend does not support 'a' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   "aka-proxy-artists".format(orig_handle)

# %% [markdown]
# # 어노테이션1

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
size = 50
x = np.linspace(1,10,10)
y = np.linspace(1,20,10)
y2= x**2
# 차트 꾸미기
plt.plot(x,y, "b--", label="first") #차트 선색 및 크기설정
plt.plot(x,y2, "r--", label="second") #차트 선색 및 크기설정
plt.legend(loc=1)
# 화살표 시작지점
plt.annotate('분리지점',xy=(2,2), xytext=(2,20),arrowprops=dict(color="blue", width=2))
# Out:
# Text(2,20,'분리지점')

# %% [markdown]
# # 어노테이션2

# %%
# 아나콘다 있는 위치를 찾아준 후 폰트 패밀리로 폰트가 윈도우마다 
# 어떤 것이 설치되어 있는지 폰트 로케이션을 설정하고 그것을 주입시켜주면 된다.

# %%
import matplotlib
import matplotlib.font_manager as fm
font_location = "C:/Windows/Fonts/malgun.ttf"
font_name = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family = font_name)

# %%
# import matplotlib
# import matplotlib.font_manager as fm
# font_location = "c:/windows/fonts/HYNAML.TTF"
# font_name = fm.FontProperties(fname = font_location).get_name()
# matplotlib.rc('font', family = font_name)

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

# 커맨드뷰에서 차트 시연
# %matplotlib inline
size = 50
x = np.linspace(1,10,10)
y = np.linspace(1,20,10)
y2= x**2
# 차트 꾸미기
# plt.figure(20,5)
plt.plot(x,y,"b--",label="first")#차트 선색 및 크기설정
plt.plot(x,y2,"r--",label="second") #차트 선색 및 크기설정
plt.legend(loc=1)
# 화살표 시작지점
plt.annotate('분리지점',xy=(2,2), xytext=(2,20),arrowprops=dict(color="blue", width=2))
# Out:
# Text(2,20,'분리지점')
