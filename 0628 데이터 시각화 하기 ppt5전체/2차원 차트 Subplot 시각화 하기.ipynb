# %% [markdown]
# # 2차원 차트 Subplot

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

#데이터 정의 첫번째 컬럼은 정규분포, 두번째 컬럼은 *100
y=np.random.standard_normal((20,2))
y[:,1] = y[:,1]*100

plt.figure(figsize=(7,5))
plt.subplot(121)
plt.plot(y[:, 0], 'b',lw=1.5, label = '1st')
plt.plot(y[:, 0], 'o')
plt.grid(True)
plt.legend(loc=0)
plt.ylabel('value')
plt.title('A Simple Plot')
plt.subplot(122)
plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.plot(y[:, 1], 'go')
plt.grid(True)
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
# Out:
# Text(0,0.5,'value')

# %% [markdown]
# # 2차원 차트 그리기

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

#데이터 정의 첫번째 컬럼은 정규분포, 두번째 컬럼은 *100
y=np.random.standard_normal((20,2))
y[:,1] = y[:,1]*100

#첫번째 컬럼자료를 첫번째(왼쪽) 축에 대응하여 그림
fig, ax1 = plt.subplots()
plt.plot(y[:, 0], 'b', lw=1.5, label = '1st')
plt.plot(y[:, 0], 'bo')
plt.grid(True)
plt.legend(loc=4)
plt.xlabel('index')
plt.ylabel('value 1st')
plt.title('A Simple Plot')
#두번째 컬럼자료를 두번쨰(오른쪽) 축에 대응하여 그림
ax2 = ax1.twinx()
plt.plot(y[:, 1], 'g', lw=1.5, label = '2nd')
plt.plot(y[:, 1], 'go')
plt.legend(loc=0)
plt.ylabel('value 2nd')
# Out:
# Text(0,0.5,'value 2nd')

# %% [markdown]
# # 예제

# %%
# 고객 데이터 customerdata를 활용하여 scatter plot을
# 그려보세요
# x축 → DEVICECOUNT
# y축 → PRODUCTAGE
# 컬러 → CUSTTYPE

# %%
import pandas as pd 
import pymssql 
from sqlalchemy import create_engine

# %%
engine = create_engine('oracle+cx_oracle://kopo:kopo@192.168.110.112:1521/orcl')

# %%
# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM customerdata', engine) 
customerData.head(4)
# Out:
#    custid     avgprice  emi  devicecount  productage          custtype
# 0  E11917  3516.500000    2          5.5    2.087540  Big-Screen-lover
# 1  E16075  3418.048887    2          4.2    2.771469      Sleeping-dog
# 2  E16221  3408.300000    2          5.0    1.988682  Big-Screen-lover
# 3  E18145  3408.300000    2          4.9    1.521029  Big-Screen-lover

# %%
#pip install seasborn
import seaborn as sns
# %matplotlib inline

# %%
sns.jointplot(x= 'DEVICECOUNT', y = 'PRODUCTAGE', data = tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5fbd30c671c8> in <module>()
# ----> 1 sns.jointplot(x= 'DEVICECOUNT', y = 'PRODUCTAGE', data = tips)
#
# NameError: name 'sns' is not defined

# %%
#필요 라이브러리 정의
import numpy as np
import matplotlib.pyplot as plt

#데이터 정의 정규분포 50개행 컬럼2개
y=np.random.standard_normal((50,2))
# 0~10까지 랜덤숫자 50개
c= np.random.randint(0,10,len(y))

plt.figure(figsize=(7,5))
plt.scatter(y[:,0],y[:,1],marker='o',c=c)
plt.colorbar(CUSTTYPE)

plt.xlabel('DEVICECOUNT')
plt.ylabel('PRODUCTAGE')
plt.title('Scatter plt')
#plt.scatter?
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-5bd00746c68f> in <module>()
#      10 plt.figure(figsize=(7,5))
#      11 plt.scatter(y[:,0],y[:,1],marker='o',c=c)
# ---> 12 plt.colorbar(CUSTTYPE)
#      13
#      14 plt.xlabel('DEVICECOUNT')
#
# NameError: name 'CUSTTYPE' is not defined
